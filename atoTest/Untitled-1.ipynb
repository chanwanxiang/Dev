# %%
# 冒泡排序
def bubbleSort(nums):
    for i in range(len(nums) - 1):
        for j in range(len(nums) - 1 - i):
            if nums[j] > nums[j + 1]:
                nums[j], nums[j + 1] = nums[j + 1], nums[j]
    return nums

print(bubbleSort([5, 4, 3, 2, 1]))
# Out:
# [1, 2, 3, 4, 5]

# %%
print('')
print(type(''))
# Out:
# <class 'str'>

# %%
# 两数之和
def twoSum(nums, target):
    num_dict = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in num_dict:
            return [num_dict[complement], i]
        num_dict[num] = i
    return []

# %%
# 输出字符串中包含最长不重复子串的长度
def lengthOfLongestSubstring(s: str) -> int:
    if len(s) == 0:
        return 0
    max_len = 1
    start = 0
    dic = {}
    for i in range(len(s)):
        if s[i] in dic and start <= dic[s[i]]:
            start = dic[s[i]] + 1
        else:
            max_len = max(max_len, i - start + 1)

# %%
# 统计给定子字符串在字符串中出现的次数
def count_substring(string, substring):
    count = 0
    index = 0
    while index < len(string):
        index = string.find(substring, index)
        if index == -1:
            break
        count += 1
        index += len(substring)
    return count

# %%
def countSubstring(str, sub):
    count = 0
    index = 0
    while index < len(str):
        index = str.find(sun, index)
        if index == -1:
            return count
        count += 1
        index += len(sub)
    
    return count

# %%
# 给一个json文件，写一个函数去完成json文件中品类特征的修改
def modify_json(json_file, category, feature, value):
    # 读取JSON文件
    with open(json_file, 'r') as f:
        data = json.load(f)

    # 找到指定的品类
    for item in data['categories']:
        if item['name'] == category:
            # 修改特征值
            item[feature] = value
            break

    # 保存修改后的JSON文件
    with open(json_file, 'w') as f:

# %%
# 解析一个json文件，统计出json文件中某个字段出现次数以及出现次数最多的元素
import json
from collections import Counter

def count_field_occurrences(json_file):
    with open(json_file, 'r') as file:
        data = json.load(file)

    # 创建一个Counter对象，用于统计字段出现的次数
    counter = Counter()

    # 递归遍历JSON数据，统计字段出现的次数
    def traverse(obj):
        if isinstance(obj, dict):
            for key, value in obj.items():

# %%
# 用shell编写一个日志文件里error出现的次数
BIN/bash -c "grep -c 'error' logfile"

# %%
# 统计abc.log文件中error出现的次数
BIN/bash -c "grep -c 'error' abc.log"

# %%
import json

dt = {'name': 'John',
      'age':                        30,

      'city': 'New Yo                 rk'}

print(json.dumps(dt), type(json.dumps(dt)))
# Out:
# {"name": "John", "age": 30, "city": "New Yo                 rk"} <class 'str'>
